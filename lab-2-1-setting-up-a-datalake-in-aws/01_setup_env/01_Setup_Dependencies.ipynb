# %% [markdown]
# # Setup All Workshop Dependencies

# %% [markdown]
# ## Set up Python enviroment using the "requirements.txt" file

# %%
# Read and validate requirements.txt file
with open("requirements.txt", "r", encoding="utf-8") as f:
    for i, line in enumerate(f, 1):
        print(i, repr(line))
# Out:
# 1 '# Python 3.12.14-compatible dependencies with AWS/SageMaker Labs\n'
# 2 '# Keep SageMaker v2 because the lab uses sagemaker.session.Session\n'
# 3 '# Boto3 installs botocore automatically\n'
# 4 'boto3\n'
# 5 'sagemaker==2.235.0\n'
# 6 'sagemaker-experiments==0.1.45\n'
# 7 'numpy==1.26.4\n'
# 8 'protobuf==4.25.9\n'
# 9 '\n'
# 10 '# Used by later Data Lake and visualization notebooks.\n'
# 11 'awscli\n'
# 12 'smdebug\n'
# 13 'pyathena\n'
# 14 'awswrangler\n'
# 15 'matplotlib\n'
# 16 'seaborn\n'
# 17 'pandas\n'
# 18 'scikit-learn'

# %%
# !pip install --upgrade pip
# !pip install -r requirements.txt

# %%
# Check packages
# !pip list
# Out:
# Package                                     Version
# ------------------------------------------- -----------
# absl-py                                     2.5.0
# accelerate                                  1.14.0
# adagio                                      0.2.6
# aiobotocore                                 3.9.0
# aiohappyeyeballs                            2.7.1
# aiohttp                                     3.14.3
# aiohttp-cors                                0.8.1
# aioitertools                                0.13.0
# aiosignal                                   1.4.0
# aiosqlite                                   0.19.0
# alembic                                     1.19.1
# altair                                      6.2.2
# amazon_sagemaker_jupyter_scheduler          3.2.2
# amazon-sagemaker-sql-editor                 0.2.6
# amazon-sagemaker-sql-execution              0.1.9
# amazon-sagemaker-sql-magic                  0.1.4
# ...

# %% [markdown]
# # Set up dependencies and share across multiple notebooks

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# ingest_create_athena_db_passed                        -> True
# ingest_create_athena_table_parquet_passed             -> True
# ingest_create_athena_table_tsv_passed                 -> True
# s3_private_path_tsv                                   -> 's3://sagemaker-us-east-1-944202758041/amazon-revi
# s3_public_path_tsv                                    -> 's3://aai-540/amazon-reviews-pds/tsv'
# setup_dependencies_passed                             -> True
# setup_s3_bucket_passed                                -> True

# %% [markdown]
# # Release Resources
# ## Release Kernel for this notebook - free resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
