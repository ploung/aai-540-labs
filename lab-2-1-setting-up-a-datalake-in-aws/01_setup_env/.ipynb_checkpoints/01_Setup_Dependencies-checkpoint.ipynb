# %% [markdown]
# # Setup All Workshop Dependencies
#
# ## _Note:  This Notebook Will Take A Few Minutes To Complete._
#
# ## _Please Be Patient._

# %% [markdown]
# # Set up Python enviroment using the "requirements.txt" file

# %%
with open("requirements.txt", "r", encoding="utf-8") as f:
    for i, line in enumerate(f, 1):
        print(i, repr(line))
# Out:
# 1 '# Python 3.12.14-compatible dependencies with AWS/SageMaker Labs\n'
# 2 'awscli\n'
# 3 'boto3\n'
# 4 'botocore\n'
# 5 'sagemaker\n'
# 6 'smdebug\n'
# 7 'sagemaker-experiments\n'
# 8 'pyathena\n'
# 9 'awswrangler\n'
# 10 'matplotlib\n'
# 11 'seaborn\n'
# 12 'protobuf\n'
# 13 'pandas\n'
# 14 'numpy\n'
# 15 'scikit-learn'

# %%
# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.12/site-packages (26.2.1)
# Requirement already satisfied: awscli in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.36.0)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.35.0)
# Requirement already satisfied: botocore in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.35.59)
# Requirement already satisfied: sagemaker in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2.235.0)
# Requirement already satisfied: smdebug in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.0.34)
# Requirement already satisfied: sagemaker-experiments in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (0.1.45)
# Requirement already satisfied: pyathena in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (3.8.0)
# Requirement already satisfied: awswrangler in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (3.11.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (3.9.2)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (3.20.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (2.3.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.7.2)
# Requirement already satisfied: docutils<0.17,>=0.10 in /opt/conda/lib/python3.12/site-packages (from awscli->-r requirements.txt (line 2)) (0.16)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from awscli->-r requirements.txt (line 2)) (0.10.4)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /opt/conda/lib/python3.12/site-packages (from awscli->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /opt/conda/lib/python3.12/site-packages (from awscli->-r requirements.txt (line 2)) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/conda/lib/python3.12/site-packages (from awscli->-r requirements.txt (line 2)) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from botocore->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore->-r requirements.txt (line 4)) (1.26.20)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.12/site-packages (from rsa<4.8,>=3.1.2->awscli->-r requirements.txt (line 2)) (0.6.4)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: docker in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (7.2.0)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (6.10.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (4.23.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (24.2)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (0.3.5)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (4.11.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (7.1.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (2.34.2)
# Requirement already satisfied: sagemaker-core<2.0.0,>=1.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (1.0.16)
# Requirement already satisfied: schema in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (0.7.8)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.12/site-packages (from sagemaker->-r requirements.txt (line 5)) (4.70.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.12/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (2.13.4)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/conda/lib/python3.12/site-packages (from sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (4.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker->-r requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker->-r requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from jsonschema->sagemaker->-r requirements.txt (line 5)) (0.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (0.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.12/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (2.21.0)
# Requirement already satisfied: pyinstrument==3.4.2 in /opt/conda/lib/python3.12/site-packages (from smdebug->-r requirements.txt (line 6)) (3.4.2)
# Requirement already satisfied: pyinstrument-cext>=0.2.2 in /opt/conda/lib/python3.12/site-packages (from pyinstrument==3.4.2->smdebug->-r requirements.txt (line 6)) (0.2.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.12/site-packages (from pyathena->-r requirements.txt (line 8)) (2026.6.0)
# Requirement already satisfied: tenacity>=4.1.0 in /opt/conda/lib/python3.12/site-packages (from pyathena->-r requirements.txt (line 8)) (9.1.4)
# Requirement already satisfied: pyarrow<19.0.0,>=8.0.0 in /opt/conda/lib/python3.12/site-packages (from awswrangler->-r requirements.txt (line 9)) (18.1.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from awswrangler->-r requirements.txt (line 9)) (84.0.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 13)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas->-r requirements.txt (line 13)) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 15)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 15)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.12/site-packages (from scikit-learn->-r requirements.txt (line 15)) (3.6.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<2.0.0,>=1.0.0->sagemaker->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker->-r requirements.txt (line 5)) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker->-r requirements.txt (line 5)) (3.19)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/conda/lib/python3.12/site-packages (from requests->sagemaker->-r requirements.txt (line 5)) (2026.7.22)
# Requirement already satisfied: ppft>=1.7.8 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker->-r requirements.txt (line 5)) (1.7.8)
# Requirement already satisfied: dill>=0.4.1 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker->-r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: pox>=0.3.7 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker->-r requirements.txt (line 5)) (0.3.7)
# Requirement already satisfied: multiprocess>=0.70.19 in /opt/conda/lib/python3.12/site-packages (from pathos->sagemaker->-r requirements.txt (line 5)) (0.70.19)

# %% [markdown]
# # Summarize

# %%
# !python --version

# %%
# !pip list

# %% [markdown]
# # Set up dependencies to use across notebooks

# %%
setup_dependencies_passed = True

# %%
# %store setup_dependencies_passed
# Out:
# Stored 'setup_dependencies_passed' (bool)

# %%
# %store
# Out:
# Stored variables and their in-db values:
# setup_dependencies_passed             -> True

# %% [markdown]
# # Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>
# Out:
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
